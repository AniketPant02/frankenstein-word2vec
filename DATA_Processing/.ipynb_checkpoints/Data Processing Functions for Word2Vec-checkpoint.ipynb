# %% [markdown]
# # Data Processing Functions for Word2Vec

# %%
import pandas as pd
import numpy as np

# %%
# importing all necessary modules 
from nltk.tokenize import sent_tokenize, word_tokenize 
from nltk.corpus import stopwords
import warnings 
  
warnings.filterwarnings(action = 'ignore') 
  
import gensim 
from gensim.models import Word2Vec 
  
#  Reads ‘alice.txt’ file 
sample = open("../DATA_Store/frankenstein_fulltext.txt", "r", encoding="utf8") 
s = sample.read() 
  
# Replaces escape character with space 
f = s.replace("\n", " ")
  
data = [] 
  
# iterate through each sentence in the file 
for i in sent_tokenize(f): 
    temp = [] 
      
    # tokenize the sentence into words 
    for j in word_tokenize(i): 
        temp.append(j.lower())  # all words are lower case
  
    data.append(temp)

# %%
# NEED TO IMPLEMENT PORTER STEMMER and REMOVE PUNCTUATION

# %%
# remove stop words
stop_words = set(stopwords.words('english')) 
filtered_data = [[w for w in data[i] if not w in stop_words] for i in range(len(data))]

# %%
filtered_data
# Out:
# [['mrs.', 'saville', ',', 'england', '.'],
#  ['st.', 'petersburgh', ',', 'dec.', '11th', ',', '17—', '.'],
#  ['rejoice',
#   'hear',
#   'disaster',
#   'accompanied',
#   'commencement',
#   'enterprise',
#   'regarded',
#   'evil',
#   'forebodings',
#   '.'],
#  ['arrived',
#   'yesterday',
#   ',',
#   'first',
#   'task',
#   'assure',
#   'dear',
#   'sister',
#   'welfare',
#   'increasing',
#   'confidence',
#   'success',
#   'undertaking',
#   '.'],
#  ['already',
#   'far',
#   'north',
#   'london',
#   ',',
#   'walk',
#   'streets',
#   'petersburgh',
#   ',',
#   'feel',
#   'cold',
#   'northern',
#   'breeze',
#   'play',
#   'upon',
#   'cheeks',
#   ',',
#   'braces',
#   'nerves',
#   'fills',
#   'delight',
#   '.'],
#  ['understand', 'feeling', '?'],
#  ['breeze',
#   ',',
#   'travelled',
#   'regions',
#   'towards',
#   'advancing',
#   ',',
#   'gives',
#   'foretaste',
#   'icy',
#   'climes',
#   '.'],
#  ['inspirited',
#   'wind',
#   'promise',
#   ',',
#   'daydreams',
#   'become',
#   'fervent',
#   'vivid',
#   '.'],
#  ['try',
#   'vain',
#   'persuaded',
#   'pole',
#   'seat',
#   'frost',
#   'desolation',
#   ';',
#   'ever',
#   'presents',
#   'imagination',
#   'region',
#   'beauty',
#   'delight',
#   '.'],
#  [',',
#   'margaret',
#   ',',
#   'sun',
#   'ever',
#   'visible',
#   ',',
#   'broad',
#   'disk',
#   'skirting',
#   'horizon',
#   'diffusing',
#   'perpetual',
#   'splendour',
#   '.'],
#  ['there—for',
#   'leave',
#   ',',
#   'sister',
#   ',',
#   'put',
#   'trust',
#   'preceding',
#   'navigators—there',
#   'snow',
#   'frost',
#   'banished',
#   ';',
#   ',',
#   'sailing',
#   'calm',
#   'sea',
#   ',',
#   'may',
#   'wafted',
#   'land',
#   'surpassing',
#   'wonders',
#   'beauty',
#   'every',
#   'region',
#   'hitherto',
#   'discovered',
#   'habitable',
#   'globe',
#   '.'],
#  ['productions',
#   'features',
#   'may',
#   'without',
#   'example',
#   ',',
#   'phenomena',
#   'heavenly',
#   'bodies',
#   'undoubtedly',
#   'undiscovered',
#   'solitudes',
#   '.'],
#  ['may', 'expected', 'country', 'eternal', 'light', '?'],
#  ['may',
#   'discover',
#   'wondrous',
#   'power',
#   'attracts',
#   'needle',
#   'may',
#   'regulate',
#   'thousand',
#   'celestial',
#   'observations',
#   'require',
#   'voyage',
#   'render',
#   'seeming',
#   'eccentricities',
#   'consistent',
#   'ever',
#   '.'],
#  ['shall',
#   'satiate',
#   'ardent',
#   'curiosity',
#   'sight',
#   'part',
#   'world',
#   'never',
#   'visited',
#   ',',
#   'may',
#   'tread',
#   'land',
#   'never',
#   'imprinted',
#   'foot',
#   'man',
#   '.'],
#  ['enticements',
#   ',',
#   'sufficient',
#   'conquer',
#   'fear',
#   'danger',
#   'death',
#   'induce',
#   'commence',
#   'laborious',
#   'voyage',
#   'joy',
#   'child',
#   'feels',
#   'embarks',
#   'little',
#   'boat',
#   ',',
#   'holiday',
#   'mates',
#   ',',
#   'expedition',
#   'discovery',
#   'native',
#   'river',
#   '.'],
#  ['supposing',
#   'conjectures',
#   'false',
#   ',',
#   'contest',
#   'inestimable',
#   'benefit',
#   'shall',
#   'confer',
#   'mankind',
#   ',',
#   'last',
#   'generation',
#   ',',
#   'discovering',
#   'passage',
#   'near',
#   'pole',
#   'countries',
#   ',',
#   'reach',
#   'present',
#   'many',
#   'months',
#   'requisite',
#   ';',
#   'ascertaining',
#   'secret',
#   'magnet',
#   ',',
#   ',',
#   'possible',
#   ',',
#   'effected',
#   'undertaking',
#   'mine',
#   '.'],
#  ['reflections',
#   'dispelled',
#   'agitation',
#   'began',
#   'letter',
#   ',',
#   'feel',
#   'heart',
#   'glow',
#   'enthusiasm',
#   'elevates',
#   'heaven',
#   ',',
#   'nothing',
#   'contributes',
#   'much',
#   'tranquillise',
#   'mind',
#   'steady',
#   'purpose—a',
#   'point',
#   'soul',
#   'may',
#   'fix',
#   'intellectual',
#   'eye',
#   '.'],
#  ['expedition', 'favourite', 'dream', 'early', 'years', '.'],
#  ['read',
#   'ardour',
#   'accounts',
#   'various',
#   'voyages',
#   'made',
#   'prospect',
#   'arriving',
#   'north',
#   'pacific',
#   'ocean',
#   'seas',
#   'surround',
#   'pole',
#   '.'],
#  ['may',
#   'remember',
#   'history',
#   'voyages',
#   'made',
#   'purposes',
#   'discovery',
#   'composed',
#   'whole',
#   'good',
#   'uncle',
#   'thomas',
#   '’',
#   'library',
#   '.'],
#  ['education',
#   'neglected',
#   ',',
#   'yet',
#   'passionately',
#   'fond',
#   'reading',
#   '.'],
#  ['volumes',
#   'study',
#   'day',
#   'night',
#   ',',
#   'familiarity',
#   'increased',
#   'regret',
#   'felt',
#   ',',
#   'child',
#   ',',
#   'learning',
#   'father',
#   '’',
#   'dying',
#   'injunction',
#   'forbidden',
#   'uncle',
#   'allow',
#   'embark',
#   'seafaring',
#   'life',
#   '.'],
#  ['visions',
#   'faded',
#   'perused',
#   ',',
#   'first',
#   'time',
#   ',',
#   'poets',
#   'whose',
#   'effusions',
#   'entranced',
#   'soul',
#   'lifted',
#   'heaven',
#   '.'],
#  ['also',
#   'became',
#   'poet',
#   'one',
#   'year',
#   'lived',
#   'paradise',
#   'creation',
#   ';',
#   'imagined',
#   'also',
#   'might',
#   'obtain',
#   'niche',
#   'temple',
#   'names',
#   'homer',
#   'shakespeare',
#   'consecrated',
#   '.'],
#  ['well', 'acquainted', 'failure', 'heavily', 'bore', 'disappointment', '.'],
#  ['time',
#   'inherited',
#   'fortune',
#   'cousin',
#   ',',
#   'thoughts',
#   'turned',
#   'channel',
#   'earlier',
#   'bent',
#   '.'],
#  ['six',
#   'years',
#   'passed',
#   'since',
#   'resolved',
#   'present',
#   'undertaking',
#   '.'],
#  [',',
#   'even',
#   ',',
#   'remember',
#   'hour',
#   'dedicated',
#   'great',
#   'enterprise',
#   '.'],
#  ['commenced', 'inuring', 'body', 'hardship', '.'],
#  ['accompanied',
#   'whale-fishers',
#   'several',
#   'expeditions',
#   'north',
#   'sea',
#   ';',
#   'voluntarily',
#   'endured',
#   'cold',
#   ',',
#   'famine',
#   ',',
#   'thirst',
#   ',',
#   'want',
#   'sleep',
#   ';',
#   'often',
#   'worked',
#   'harder',
#   'common',
#   'sailors',
#   'day',
#   'devoted',
#   'nights',
#   'study',
#   'mathematics',
#   ',',
#   'theory',
#   'medicine',
#   ',',
#   'branches',
#   'physical',
#   'science',
#   'naval',
#   'adventurer',
#   'might',
#   'derive',
#   'greatest',
#   'practical',
#   'advantage',
#   '.'],
#  ['twice',
#   'actually',
#   'hired',
#   'under-mate',
#   'greenland',
#   'whaler',
#   ',',
#   'acquitted',
#   'admiration',
#   '.'],
#  ['must',
#   'felt',
#   'little',
#   'proud',
#   'captain',
#   'offered',
#   'second',
#   'dignity',
#   'vessel',
#   'entreated',
#   'remain',
#   'greatest',
#   'earnestness',
#   ',',
#   'valuable',
#   'consider',
#   'services',
#   '.'],
#  [',',
#   'dear',
#   'margaret',
#   ',',
#   'deserve',
#   'accomplish',
#   'great',
#   'purpose',
#   '?'],
#  ['life',
#   'might',
#   'passed',
#   'ease',
#   'luxury',
#   ',',
#   'preferred',
#   'glory',
#   'every',
#   'enticement',
#   'wealth',
#   'placed',
#   'path',
#   '.'],
#  ['oh', ',', 'encouraging', 'voice', 'would', 'answer', 'affirmative', '!'],
#  ['courage',
#   'resolution',
#   'firm',
#   ';',
#   'hopes',
#   'fluctuate',
#   ',',
#   'spirits',
#   'often',
#   'depressed',
#   '.'],
#  ['proceed',
#   'long',
#   'difficult',
#   'voyage',
#   ',',
#   'emergencies',
#   'demand',
#   'fortitude',
#   ':',
#   'required',
#   'raise',
#   'spirits',
#   'others',
#   ',',
#   'sometimes',
#   'sustain',
#   ',',
#   'failing',
#   '.'],
#  ['favourable', 'period', 'travelling', 'russia', '.'],
#  ['fly',
#   'quickly',
#   'snow',
#   'sledges',
#   ';',
#   'motion',
#   'pleasant',
#   ',',
#   ',',
#   'opinion',
#   ',',
#   'far',
#   'agreeable',
#   'english',
#   'stagecoach',
#   '.'],
#  ['cold',
#   'excessive',
#   ',',
#   'wrapped',
#   'furs—a',
#   'dress',
#   'already',
#   'adopted',
#   ',',
#   'great',
#   'difference',
#   'walking',
#   'deck',
#   'remaining',
#   'seated',
#   'motionless',
#   'hours',
#   ',',
#   'exercise',
#   'prevents',
#   'blood',
#   'actually',
#   'freezing',
#   'veins',
#   '.'],
#  ['ambition',
#   'lose',
#   'life',
#   'post-road',
#   'st.',
#   'petersburgh',
#   'archangel',
#   '.'],
#  ['shall',
#   'depart',
#   'latter',
#   'town',
#   'fortnight',
#   'three',
#   'weeks',
#   ';',
#   'intention',
#   'hire',
#   'ship',
#   ',',
#   'easily',
#   'done',
#   'paying',
#   'insurance',
#   'owner',
#   ',',
#   'engage',
#   'many',
#   'sailors',
#   'think',
#   'necessary',
#   'among',
#   'accustomed',
#   'whale-fishing',
#   '.'],
#  ['intend', 'sail', 'month', 'june', ';', 'shall', 'return', '?'],
#  ['ah', ',', 'dear', 'sister', ',', 'answer', 'question', '?'],
#  ['succeed',
#   ',',
#   'many',
#   ',',
#   'many',
#   'months',
#   ',',
#   'perhaps',
#   'years',
#   ',',
#   'pass',
#   'may',
#   'meet',
#   '.'],
#  ['fail', ',', 'see', 'soon', ',', 'never', '.'],
#  ['farewell', ',', 'dear', ',', 'excellent', 'margaret', '.'],
#  ['heaven',
#   'shower',
#   'blessings',
#   ',',
#   'save',
#   ',',
#   'may',
#   'testify',
#   'gratitude',
#   'love',
#   'kindness',
#   '.'],
#  ['affectionate',
#   'brother',
#   ',',
#   'r.',
#   'walton',
#   'mrs.',
#   'saville',
#   ',',
#   'england',
#   '.'],
#  ['archangel', ',', '28th', 'march', ',', '17—', '.'],
#  ['slowly', 'time', 'passes', ',', 'encompassed', 'frost', 'snow', '!'],
#  ['yet', 'second', 'step', 'taken', 'towards', 'enterprise', '.'],
#  ['hired',
#   'vessel',
#   'occupied',
#   'collecting',
#   'sailors',
#   ';',
#   'already',
#   'engaged',
#   'appear',
#   'men',
#   'depend',
#   'certainly',
#   'possessed',
#   'dauntless',
#   'courage',
#   '.'],
#  ['one',
#   'want',
#   'never',
#   'yet',
#   'able',
#   'satisfy',
#   ',',
#   'absence',
#   'object',
#   'feel',
#   'severe',
#   'evil',
#   ',',
#   'friend',
#   ',',
#   'margaret',
#   ':',
#   'glowing',
#   'enthusiasm',
#   'success',
#   ',',
#   'none',
#   'participate',
#   'joy',
#   ';',
#   'assailed',
#   'disappointment',
#   ',',
#   'one',
#   'endeavour',
#   'sustain',
#   'dejection',
#   '.'],
#  ['shall',
#   'commit',
#   'thoughts',
#   'paper',
#   ',',
#   'true',
#   ';',
#   'poor',
#   'medium',
#   'communication',
#   'feeling',
#   '.'],
#  ['desire',
#   'company',
#   'man',
#   'could',
#   'sympathise',
#   ',',
#   'whose',
#   'eyes',
#   'would',
#   'reply',
#   'mine',
#   '.'],
#  ['may',
#   'deem',
#   'romantic',
#   ',',
#   'dear',
#   'sister',
#   ',',
#   'bitterly',
#   'feel',
#   'want',
#   'friend',
#   '.'],
#  ['one',
#   'near',
#   ',',
#   'gentle',
#   'yet',
#   'courageous',
#   ',',
#   'possessed',
#   'cultivated',
#   'well',
#   'capacious',
#   'mind',
#   ',',
#   'whose',
#   'tastes',
#   'like',
#   ',',
#   'approve',
#   'amend',
#   'plans',
#   '.'],
#  ['would', 'friend', 'repair', 'faults', 'poor', 'brother', '!'],
#  ['ardent', 'execution', 'impatient', 'difficulties', '.'],
#  ['still',
#   'greater',
#   'evil',
#   'self-educated',
#   ':',
#   'first',
#   'fourteen',
#   'years',
#   'life',
#   'ran',
#   'wild',
#   'common',
#   'read',
#   'nothing',
#   'uncle',
#   'thomas',
#   '’',
#   'books',
#   'voyages',
#   '.'],
#  ['age',
#   'became',
#   'acquainted',
#   'celebrated',
#   'poets',
#   'country',
#   ';',
#   'ceased',
#   'power',
#   'derive',
#   'important',
#   'benefits',
#   'conviction',
#   'perceived',
#   'necessity',
#   'becoming',
#   'acquainted',
#   'languages',
#   'native',
#   'country',
#   '.'],
#  ['twenty-eight',
#   'reality',
#   'illiterate',
#   'many',
#   'schoolboys',
#   'fifteen',
#   '.'],
#  ['true',
#   'thought',
#   'daydreams',
#   'extended',
#   'magnificent',
#   ',',
#   'want',
#   '(',
#   'painters',
#   'call',
#   ')',
#   'keeping',
#   ';',
#   'greatly',
#   'need',
#   'friend',
#   'would',
#   'sense',
#   'enough',
#   'despise',
#   'romantic',
#   ',',
#   'affection',
#   'enough',
#   'endeavour',
#   'regulate',
#   'mind',
#   '.'],
#  ['well',
#   ',',
#   'useless',
#   'complaints',
#   ';',
#   'shall',
#   'certainly',
#   'find',
#   'friend',
#   'wide',
#   'ocean',
#   ',',
#   'even',
#   'archangel',
#   ',',
#   'among',
#   'merchants',
#   'seamen',
#   '.'],
#  ['yet',
#   'feelings',
#   ',',
#   'unallied',
#   'dross',
#   'human',
#   'nature',
#   ',',
#   'beat',
#   'even',
#   'rugged',
#   'bosoms',
#   '.'],
#  ['lieutenant',
#   ',',
#   'instance',
#   ',',
#   'man',
#   'wonderful',
#   'courage',
#   'enterprise',
#   ';',
#   'madly',
#   'desirous',
#   'glory',
#   ',',
#   'rather',
#   ',',
#   'word',
#   'phrase',
#   'characteristically',
#   ',',
#   'advancement',
#   'profession',
#   '.'],
#  ['englishman',
#   ',',
#   'midst',
#   'national',
#   'professional',
#   'prejudices',
#   ',',
#   'unsoftened',
#   'cultivation',
#   ',',
#   'retains',
#   'noblest',
#   'endowments',
#   'humanity',
#   '.'],
#  ['first',
#   'became',
#   'acquainted',
#   'board',
#   'whale',
#   'vessel',
#   ';',
#   'finding',
#   'unemployed',
#   'city',
#   ',',
#   'easily',
#   'engaged',
#   'assist',
#   'enterprise',
#   '.'],
#  ['master',
#   'person',
#   'excellent',
#   'disposition',
#   'remarkable',
#   'ship',
#   'gentleness',
#   'mildness',
#   'discipline',
#   '.'],
#  ['circumstance',
#   ',',
#   'added',
#   'well-known',
#   'integrity',
#   'dauntless',
#   'courage',
#   ',',
#   'made',
#   'desirous',
#   'engage',
#   '.'],
#  ['youth',
#   'passed',
#   'solitude',
#   ',',
#   'best',
#   'years',
#   'spent',
#   'gentle',
#   'feminine',
#   'fosterage',
#   ',',
#   'refined',
#   'groundwork',
#   'character',
#   'overcome',
#   'intense',
#   'distaste',
#   'usual',
#   'brutality',
#   'exercised',
#   'board',
#   'ship',
#   ':',
#   'never',
#   'believed',
#   'necessary',
#   ',',
#   'heard',
#   'mariner',
#   'equally',
#   'noted',
#   'kindliness',
#   'heart',
#   'respect',
#   'obedience',
#   'paid',
#   'crew',
#   ',',
#   'felt',
#   'peculiarly',
#   'fortunate',
#   'able',
#   'secure',
#   'services',
#   '.'],
#  ['heard',
#   'first',
#   'rather',
#   'romantic',
#   'manner',
#   ',',
#   'lady',
#   'owes',
#   'happiness',
#   'life',
#   '.'],
#  [',', 'briefly', ',', 'story', '.'],
#  ['years',
#   'ago',
#   'loved',
#   'young',
#   'russian',
#   'lady',
#   'moderate',
#   'fortune',
#   ',',
#   'amassed',
#   'considerable',
#   'sum',
#   'prize-money',
#   ',',
#   'father',
#   'girl',
#   'consented',
#   'match',
#   '.'],
#  ['saw',
#   'mistress',
#   'destined',
#   'ceremony',
#   ';',
#   'bathed',
#   'tears',
#   ',',
#   'throwing',
#   'feet',
#   ',',
#   'entreated',
#   'spare',
#   ',',
#   'confessing',
#   'time',
#   'loved',
#   'another',
#   ',',
#   'poor',
#   ',',
#   'father',
#   'would',
#   'never',
#   'consent',
#   'union',
#   '.'],
#  ['generous',
#   'friend',
#   'reassured',
#   'suppliant',
#   ',',
#   'informed',
#   'name',
#   'lover',
#   ',',
#   'instantly',
#   'abandoned',
#   'pursuit',
#   '.'],
#  ['already',
#   'bought',
#   'farm',
#   'money',
#   ',',
#   'designed',
#   'pass',
#   'remainder',
#   'life',
#   ';',
#   'bestowed',
#   'whole',
#   'rival',
#   ',',
#   'together',
#   'remains',
#   'prize-money',
#   'purchase',
#   'stock',
#   ',',
#   'solicited',
#   'young',
#   'woman',
#   '’',
#   'father',
#   'consent',
#   'marriage',
#   'lover',
#   '.'],
#  ['old',
#   'man',
#   'decidedly',
#   'refused',
#   ',',
#   'thinking',
#   'bound',
#   'honour',
#   'friend',
#   ',',
#   ',',
#   'found',
#   'father',
#   'inexorable',
#   ',',
#   'quitted',
#   'country',
#   ',',
#   'returned',
#   'heard',
#   'former',
#   'mistress',
#   'married',
#   'according',
#   'inclinations',
#   '.'],
#  ['“', 'noble', 'fellow', '!', '”', 'exclaim', '.'],
#  [';',
#   'wholly',
#   'uneducated',
#   ':',
#   'silent',
#   'turk',
#   ',',
#   'kind',
#   'ignorant',
#   'carelessness',
#   'attends',
#   ',',
#   ',',
#   'renders',
#   'conduct',
#   'astonishing',
#   ',',
#   'detracts',
#   'interest',
#   'sympathy',
#   'otherwise',
#   'would',
#   'command',
#   '.'],
#  ['yet',
#   'suppose',
#   ',',
#   'complain',
#   'little',
#   'conceive',
#   'consolation',
#   'toils',
#   'may',
#   'never',
#   'know',
#   ',',
#   'wavering',
#   'resolutions',
#   '.'],
#  ['fixed',
#   'fate',
#   ',',
#   'voyage',
#   'delayed',
#   'weather',
#   'shall',
#   'permit',
#   'embarkation',
#   '.'],
#  ['winter',
#   'dreadfully',
#   'severe',
#   ',',
#   'spring',
#   'promises',
#   'well',
#   ',',
#   'considered',
#   'remarkably',
#   'early',
#   'season',
#   ',',
#   'perhaps',
#   'may',
#   'sail',
#   'sooner',
#   'expected',
#   '.'],
#  ['shall',
#   'nothing',
#   'rashly',
#   ':',
#   'know',
#   'sufficiently',
#   'confide',
#   'prudence',
#   'considerateness',
#   'whenever',
#   'safety',
#   'others',
#   'committed',
#   'care',
#   '.'],
#  ['describe', 'sensations', 'near', 'prospect', 'undertaking', '.'],
#  ['impossible',
#   'communicate',
#   'conception',
#   'trembling',
#   'sensation',
#   ',',
#   'half',
#   'pleasurable',
#   'half',
#   'fearful',
#   ',',
#   'preparing',
#   'depart',
#   '.'],
#  ['going',
#   'unexplored',
#   'regions',
#   ',',
#   '“',
#   'land',
#   'mist',
#   'snow',
#   ',',
#   '”',
#   'shall',
#   'kill',
#   'albatross',
#   ';',
#   'therefore',
#   'alarmed',
#   'safety',
#   'come',
#   'back',
#   'worn',
#   'woeful',
#   '“',
#   'ancient',
#   'mariner.',
#   '”',
#   'smile',
#   'allusion',
#   ',',
#   'disclose',
#   'secret',
#   '.'],
#  ['often',
#   'attributed',
#   'attachment',
#   ',',
#   'passionate',
#   'enthusiasm',
#   ',',
#   'dangerous',
#   'mysteries',
#   'ocean',
#   'production',
#   'imaginative',
#   'modern',
#   'poets',
#   '.'],
#  ['something', 'work', 'soul', 'understand', '.'],
#  ['practically',
#   'industrious—painstaking',
#   ',',
#   'workman',
#   'execute',
#   'perseverance',
#   'labour—but',
#   'besides',
#   'love',
#   'marvellous',
#   ',',
#   'belief',
#   'marvellous',
#   ',',
#   'intertwined',
#   'projects',
#   ',',
#   'hurries',
#   'common',
#   'pathways',
#   'men',
#   ',',
#   'even',
#   'wild',
#   'sea',
#   'unvisited',
#   'regions',
#   'explore',
#   '.'],
#  ['return', 'dearer', 'considerations', '.'],
#  ['shall',
#   'meet',
#   ',',
#   'traversed',
#   'immense',
#   'seas',
#   ',',
#   'returned',
#   'southern',
#   'cape',
#   'africa',
#   'america',
#   '?'],
#  ['dare',
#   'expect',
#   'success',
#   ',',
#   'yet',
#   'bear',
#   'look',
#   'reverse',
#   'picture',
#   '.'],
#  ['continue',
#   'present',
#   'write',
#   'every',
#   'opportunity',
#   ':',
#   'may',
#   'receive',
#   'letters',
#   'occasions',
#   'need',
#   'support',
#   'spirits',
#   '.'],
#  ['love', 'tenderly', '.'],
#  ['remember', 'affection', ',', 'never', 'hear', '.'],
#  ['affectionate',
#   'brother',
#   ',',
#   'robert',
#   'walton',
#   'mrs.',
#   'saville',
#   ',',
#   'england',
#   '.'],
#  ['july', '7th', ',', '17—', '.'],
#  ['dear',
#   'sister',
#   ',',
#   'write',
#   'lines',
#   'haste',
#   'say',
#   'safe—and',
#   'well',
#   'advanced',
#   'voyage',
#   '.'],
#  ['letter',
#   'reach',
#   'england',
#   'merchantman',
#   'homeward',
#   'voyage',
#   'archangel',
#   ';',
#   'fortunate',
#   ',',
#   'may',
#   'see',
#   'native',
#   'land',
#   ',',
#   'perhaps',
#   ',',
#   'many',
#   'years',
#   '.'],
#  [',',
#   'however',
#   ',',
#   'good',
#   'spirits',
#   ':',
#   'men',
#   'bold',
#   'apparently',
#   'firm',
#   'purpose',
#   ',',
#   'floating',
#   'sheets',
#   'ice',
#   'continually',
#   'pass',
#   'us',
#   ',',
#   'indicating',
#   'dangers',
#   'region',
#   'towards',
#   'advancing',
#   ',',
#   'appear',
#   'dismay',
#   '.'],
#  ['already',
#   'reached',
#   'high',
#   'latitude',
#   ';',
#   'height',
#   'summer',
#   ',',
#   'although',
#   'warm',
#   'england',
#   ',',
#   'southern',
#   'gales',
#   ',',
#   'blow',
#   'us',
#   'speedily',
#   'towards',
#   'shores',
#   'ardently',
#   'desire',
#   'attain',
#   ',',
#   'breathe',
#   'degree',
#   'renovating',
#   'warmth',
#   'expected',
#   '.'],
#  ['incidents',
#   'hitherto',
#   'befallen',
#   'us',
#   'would',
#   'make',
#   'figure',
#   'letter',
#   '.'],
#  ['one',
#   'two',
#   'stiff',
#   'gales',
#   'springing',
#   'leak',
#   'accidents',
#   'experienced',
#   'navigators',
#   'scarcely',
#   'remember',
#   'record',
#   ',',
#   'shall',
#   'well',
#   'content',
#   'nothing',
#   'worse',
#   'happen',
#   'us',
#   'voyage',
#   '.'],
#  ['adieu', ',', 'dear', 'margaret', '.'],
#  ['assured', 'sake', ',', 'well', ',', 'rashly', 'encounter', 'danger', '.'],
#  ['cool', ',', 'persevering', ',', 'prudent', '.'],
#  ['success', 'shall', 'crown', 'endeavours', '.'],
#  ['wherefore', '?'],
#  ['thus',
#   'far',
#   'gone',
#   ',',
#   'tracing',
#   'secure',
#   'way',
#   'pathless',
#   'seas',
#   ',',
#   'stars',
#   'witnesses',
#   'testimonies',
#   'triumph',
#   '.'],
#  ['still', 'proceed', 'untamed', 'yet', 'obedient', 'element', '?'],
#  ['stop', 'determined', 'heart', 'resolved', 'man', '?'],
#  ['swelling', 'heart', 'involuntarily', 'pours', 'thus', '.'],
#  ['must', 'finish', '.'],
#  ['heaven', 'bless', 'beloved', 'sister', '!'],
#  ['r.w', '.'],
#  ['mrs.', 'saville', ',', 'england', '.'],
#  ['august', '5th', ',', '17—', '.'],
#  ['strange',
#   'accident',
#   'happened',
#   'us',
#   'forbear',
#   'recording',
#   ',',
#   'although',
#   'probable',
#   'see',
#   'papers',
#   'come',
#   'possession',
#   '.'],
#  ['last',
#   'monday',
#   '(',
#   'july',
#   '31st',
#   ')',
#   'nearly',
#   'surrounded',
#   'ice',
#   ',',
#   'closed',
#   'ship',
#   'sides',
#   ',',
#   'scarcely',
#   'leaving',
#   'sea-room',
#   'floated',
#   '.'],
#  ['situation',
#   'somewhat',
#   'dangerous',
#   ',',
#   'especially',
#   'compassed',
#   'round',
#   'thick',
#   'fog',
#   '.'],
#  ['accordingly',
#   'lay',
#   ',',
#   'hoping',
#   'change',
#   'would',
#   'take',
#   'place',
#   'atmosphere',
#   'weather',
#   '.'],
#  ['two',
#   '’',
#   'clock',
#   'mist',
#   'cleared',
#   'away',
#   ',',
#   'beheld',
#   ',',
#   'stretched',
#   'every',
#   'direction',
#   ',',
#   'vast',
#   'irregular',
#   'plains',
#   'ice',
#   ',',
#   'seemed',
#   'end',
#   '.'],
#  ['comrades',
#   'groaned',
#   ',',
#   'mind',
#   'began',
#   'grow',
#   'watchful',
#   'anxious',
#   'thoughts',
#   ',',
#   'strange',
#   'sight',
#   'suddenly',
#   'attracted',
#   'attention',
#   'diverted',
#   'solicitude',
#   'situation',
#   '.'],
#  ['perceived',
#   'low',
#   'carriage',
#   ',',
#   'fixed',
#   'sledge',
#   'drawn',
#   'dogs',
#   ',',
#   'pass',
#   'towards',
#   'north',
#   ',',
#   'distance',
#   'half',
#   'mile',
#   ';',
#   'shape',
#   'man',
#   ',',
#   'apparently',
#   'gigantic',
#   'stature',
#   ',',
#   'sat',
#   'sledge',
#   'guided',
#   'dogs',
#   '.'],
#  ['watched',
#   'rapid',
#   'progress',
#   'traveller',
#   'telescopes',
#   'lost',
#   'among',
#   'distant',
#   'inequalities',
#   'ice',
#   '.'],
#  ['appearance', 'excited', 'unqualified', 'wonder', '.'],
#  [',',
#   'believed',
#   ',',
#   'many',
#   'hundred',
#   'miles',
#   'land',
#   ';',
#   'apparition',
#   'seemed',
#   'denote',
#   ',',
#   'reality',
#   ',',
#   'distant',
#   'supposed',
#   '.'],
#  ['shut',
#   ',',
#   'however',
#   ',',
#   'ice',
#   ',',
#   'impossible',
#   'follow',
#   'track',
#   ',',
#   'observed',
#   'greatest',
#   'attention',
#   '.'],
#  ['two',
#   'hours',
#   'occurrence',
#   'heard',
#   'ground',
#   'sea',
#   ',',
#   'night',
#   'ice',
#   'broke',
#   'freed',
#   'ship',
#   '.'],
#  [',',
#   'however',
#   ',',
#   'lay',
#   'morning',
#   ',',
#   'fearing',
#   'encounter',
#   'dark',
#   'large',
#   'loose',
#   'masses',
#   'float',
#   'breaking',
#   'ice',
#   '.'],
#  ['profited', 'time', 'rest', 'hours', '.'],
#  ['morning',
#   ',',
#   'however',
#   ',',
#   'soon',
#   'light',
#   ',',
#   'went',
#   'upon',
#   'deck',
#   'found',
#   'sailors',
#   'busy',
#   'one',
#   'side',
#   'vessel',
#   ',',
#   'apparently',
#   'talking',
#   'someone',
#   'sea',
#   '.'],
#  [',',
#   'fact',
#   ',',
#   'sledge',
#   ',',
#   'like',
#   'seen',
#   ',',
#   'drifted',
#   'towards',
#   'us',
#   'night',
#   'large',
#   'fragment',
#   'ice',
#   '.'],
#  ['one',
#   'dog',
#   'remained',
#   'alive',
#   ';',
#   'human',
#   'within',
#   'sailors',
#   'persuading',
#   'enter',
#   'vessel',
#   '.'],
#  [',',
#   'traveller',
#   'seemed',
#   ',',
#   'savage',
#   'inhabitant',
#   'undiscovered',
#   'island',
#   ',',
#   'european',
#   '.'],
#  ['appeared',
#   'deck',
#   'master',
#   'said',
#   ',',
#   '“',
#   'captain',
#   ',',
#   'allow',
#   'perish',
#   'open',
#   'sea.',
#   '”',
#   'perceiving',
#   ',',
#   'stranger',
#   'addressed',
#   'english',
#   ',',
#   'although',
#   'foreign',
#   'accent',
#   '.'],
#  ['“',
#   'come',
#   'board',
#   'vessel',
#   ',',
#   '”',
#   'said',
#   ',',
#   '“',
#   'kindness',
#   'inform',
#   'whither',
#   'bound',
#   '?',
#   '”',
#   'may',
#   'conceive',
#   'astonishment',
#   'hearing',
#   'question',
#   'addressed',
#   'man',
#   'brink',
#   'destruction',
#   'supposed',
#   'vessel',
#   'would',
#   'resource',
#   'would',
#   'exchanged',
#   'precious',
#   'wealth',
#   'earth',
#   'afford',
#   '.'],
#  ['replied',
#   ',',
#   'however',
#   ',',
#   'voyage',
#   'discovery',
#   'towards',
#   'northern',
#   'pole',
#   '.'],
#  ['upon',
#   'hearing',
#   'appeared',
#   'satisfied',
#   'consented',
#   'come',
#   'board',
#   '.'],
#  ['good', 'god', '!'],
#  ['margaret',
#   ',',
#   'seen',
#   'man',
#   'thus',
#   'capitulated',
#   'safety',
#   ',',
#   'surprise',
#   'would',
#   'boundless',
#   '.'],
#  ['limbs',
#   'nearly',
#   'frozen',
#   ',',
#   'body',
#   'dreadfully',
#   'emaciated',
#   'fatigue',
#   'suffering',
#   '.'],
#  ['never', 'saw', 'man', 'wretched', 'condition', '.'],
#  ['attempted',
#   'carry',
#   'cabin',
#   ',',
#   'soon',
#   'quitted',
#   'fresh',
#   'air',
#   'fainted',
#   '.'],
#  ['accordingly',
#   'brought',
#   'back',
#   'deck',
#   'restored',
#   'animation',
#   'rubbing',
#   'brandy',
#   'forcing',
#   'swallow',
#   'small',
#   'quantity',
#   '.'],
#  ['soon',
#   'showed',
#   'signs',
#   'life',
#   'wrapped',
#   'blankets',
#   'placed',
#   'near',
#   'chimney',
#   'kitchen',
#   'stove',
#   '.'],
#  ['slow',
#   'degrees',
#   'recovered',
#   'ate',
#   'little',
#   'soup',
#   ',',
#   'restored',
#   'wonderfully',
#   '.'],
#  ['two',
#   'days',
#   'passed',
#   'manner',
#   'able',
#   'speak',
#   ',',
#   'often',
#   'feared',
#   'sufferings',
#   'deprived',
#   'understanding',
#   '.'],
#  ['measure',
#   'recovered',
#   ',',
#   'removed',
#   'cabin',
#   'attended',
#   'much',
#   'duty',
#   'would',
#   'permit',
#   '.'],
#  ['never',
#   'saw',
#   'interesting',
#   'creature',
#   ':',
#   'eyes',
#   'generally',
#   'expression',
#   'wildness',
#   ',',
#   'even',
#   'madness',
#   ',',
#   'moments',
#   ',',
#   'anyone',
#   'performs',
#   'act',
#   'kindness',
#   'towards',
#   'trifling',
#   'service',
#   ',',
#   'whole',
#   'countenance',
#   'lighted',
#   ',',
#   ',',
#   'beam',
#   'benevolence',
#   'sweetness',
#   'never',
#   'saw',
#   'equalled',
#   '.'],
#  ['generally',
#   'melancholy',
#   'despairing',
#   ',',
#   'sometimes',
#   'gnashes',
#   'teeth',
#   ',',
#   'impatient',
#   'weight',
#   'woes',
#   'oppresses',
#   '.'],
#  ['guest',
#   'little',
#   'recovered',
#   'great',
#   'trouble',
#   'keep',
#   'men',
#   ',',
#   'wished',
#   'ask',
#   'thousand',
#   'questions',
#   ';',
#   'would',
#   'allow',
#   'tormented',
#   'idle',
#   'curiosity',
#   ',',
#   'state',
#   'body',
#   'mind',
#   'whose',
#   'restoration',
#   'evidently',
#   'depended',
#   'upon',
#   'entire',
#   'repose',
#   '.'],
#  [',',
#   'however',
#   ',',
#   'lieutenant',
#   'asked',
#   'come',
#   'far',
#   'upon',
#   'ice',
#   'strange',
#   'vehicle',
#   '.'],
#  ['countenance',
#   'instantly',
#   'assumed',
#   'aspect',
#   'deepest',
#   'gloom',
#   ',',
#   'replied',
#   ',',
#   '“',
#   'seek',
#   'one',
#   'fled',
#   'me.',
#   '”',
#   '“',
#   'man',
#   'pursued',
#   'travel',
#   'fashion',
#   '?',
#   '”',
#   '“',
#   'yes.',
#   '”',
#   '“',
#   'fancy',
#   'seen',
#   ',',
#   'day',
#   'picked',
#   'saw',
#   'dogs',
#   'drawing',
#   'sledge',
#   ',',
#   'man',
#   ',',
#   'across',
#   'ice.',
#   '”',
#   'aroused',
#   'stranger',
#   '’',
#   'attention',
#   ',',
#   'asked',
#   'multitude',
#   'questions',
#   'concerning',
#   'route',
#   'dæmon',
#   ',',
#   'called',
#   ',',
#   'pursued',
#   '.'],
#  ['soon',
#   ',',
#   'alone',
#   ',',
#   'said',
#   ',',
#   '“',
#   ',',
#   'doubtless',
#   ',',
#   'excited',
#   'curiosity',
#   ',',
#   'well',
#   'good',
#   'people',
#   ';',
#   'considerate',
#   'make',
#   'inquiries.',
#   '”',
#   '“',
#   'certainly',
#   ';',
#   'would',
#   'indeed',
#   'impertinent',
#   'inhuman',
#   'trouble',
#   'inquisitiveness',
#   'mine.',
#   '”',
#   '“',
#   'yet',
#   'rescued',
#   'strange',
#   'perilous',
#   'situation',
#   ';',
#   'benevolently',
#   'restored',
#   'life.',
#   '”',
#   'soon',
#   'inquired',
#   'thought',
#   'breaking',
#   'ice',
#   'destroyed',
#   'sledge',
#   '.'],
#  ['replied',
#   'could',
#   'answer',
#   'degree',
#   'certainty',
#   ',',
#   'ice',
#   'broken',
#   'near',
#   'midnight',
#   ',',
#   'traveller',
#   'might',
#   'arrived',
#   'place',
#   'safety',
#   'time',
#   ';',
#   'could',
#   'judge',
#   '.'],
#  ['time',
#   'new',
#   'spirit',
#   'life',
#   'animated',
#   'decaying',
#   'frame',
#   'stranger',
#   '.'],
#  ['manifested',
#   'greatest',
#   'eagerness',
#   'upon',
#   'deck',
#   'watch',
#   'sledge',
#   'appeared',
#   ';',
#   'persuaded',
#   'remain',
#   'cabin',
#   ',',
#   'far',
#   'weak',
#   'sustain',
#   'rawness',
#   'atmosphere',
#   '.'],
#  ['promised',
#   'someone',
#   'watch',
#   'give',
#   'instant',
#   'notice',
#   'new',
#   'object',
#   'appear',
#   'sight',
#   '.'],
#  ['journal', 'relates', 'strange', 'occurrence', 'present', 'day', '.'],
#  ['stranger',
#   'gradually',
#   'improved',
#   'health',
#   'silent',
#   'appears',
#   'uneasy',
#   'anyone',
#   'except',
#   'enters',
#   'cabin',
#   '.'],
#  ['yet',
#   'manners',
#   'conciliating',
#   'gentle',
#   'sailors',
#   'interested',
#   ',',
#   'although',
#   'little',
#   'communication',
#   '.'],
#  ['part',
#   ',',
#   'begin',
#   'love',
#   'brother',
#   ',',
#   'constant',
#   'deep',
#   'grief',
#   'fills',
#   'sympathy',
#   'compassion',
#   '.'],
#  ['must',
#   'noble',
#   'creature',
#   'better',
#   'days',
#   ',',
#   'even',
#   'wreck',
#   'attractive',
#   'amiable',
#   '.'],
#  ['said',
#   'one',
#   'letters',
#   ',',
#   'dear',
#   'margaret',
#   ',',
#   'find',
#   'friend',
#   'wide',
#   'ocean',
#   ';',
#   'yet',
#   'found',
#   'man',
#   ',',
#   'spirit',
#   'broken',
#   'misery',
#   ',',
#   'happy',
#   'possessed',
#   'brother',
#   'heart',
#   '.'],
#  ['shall',
#   'continue',
#   'journal',
#   'concerning',
#   'stranger',
#   'intervals',
#   ',',
#   'fresh',
#   'incidents',
#   'record',
#   '.'],
#  ['august', '13th', ',', '17—', '.'],
#  ['affection', 'guest', 'increases', 'every', 'day', '.'],
#  ['excites', 'admiration', 'pity', 'astonishing', 'degree', '.'],
#  ['see',
#   'noble',
#   'creature',
#   'destroyed',
#   'misery',
#   'without',
#   'feeling',
#   'poignant',
#   'grief',
#   '?'],
#  ['gentle',
#   ',',
#   'yet',
#   'wise',
#   ';',
#   'mind',
#   'cultivated',
#   ',',
#   'speaks',
#   ',',
#   'although',
#   'words',
#   'culled',
#   'choicest',
#   'art',
#   ',',
#   'yet',
#   'flow',
#   'rapidity',
#   'unparalleled',
#   'eloquence',
#   '.'],
#  ['much',
#   'recovered',
#   'illness',
#   'continually',
#   'deck',
#   ',',
#   'apparently',
#   'watching',
#   'sledge',
#   'preceded',
#   '.'],
#  ['yet',
#   ',',
#   'although',
#   'unhappy',
#   ',',
#   'utterly',
#   'occupied',
#   'misery',
#   'interests',
#   'deeply',
#   'projects',
#   'others',
#   '.'],
#  ['frequently',
#   'conversed',
#   'mine',
#   ',',
#   'communicated',
#   'without',
#   'disguise',
#   '.'],
#  ['entered',
#   'attentively',
#   'arguments',
#   'favour',
#   'eventual',
#   'success',
#   'every',
#   'minute',
#   'detail',
#   'measures',
#   'taken',
#   'secure',
#   '.'],
#  ['easily',
#   'led',
#   'sympathy',
#   'evinced',
#   'use',
#   'language',
#   'heart',
#   ',',
#   'give',
#   'utterance',
#   'burning',
#   'ardour',
#   'soul',
#   'say',
#   ',',
#   'fervour',
#   'warmed',
#   ',',
#   'gladly',
#   'would',
#   'sacrifice',
#   'fortune',
#   ',',
#   'existence',
#   ',',
#   'every',
#   'hope',
#   ',',
#   'furtherance',
#   'enterprise',
#   '.'],
#  ['one',
#   'man',
#   '’',
#   'life',
#   'death',
#   'small',
#   'price',
#   'pay',
#   'acquirement',
#   'knowledge',
#   'sought',
#   ',',
#   'dominion',
#   'acquire',
#   'transmit',
#   'elemental',
#   'foes',
#   'race',
#   '.'],
#  ['spoke',
#   ',',
#   'dark',
#   'gloom',
#   'spread',
#   'listener',
#   '’',
#   'countenance',
#   '.'],
#  ['first',
#   'perceived',
#   'tried',
#   'suppress',
#   'emotion',
#   ';',
#   'placed',
#   'hands',
#   'eyes',
#   ',',
#   'voice',
#   'quivered',
#   'failed',
#   'beheld',
#   'tears',
#   'trickle',
#   'fast',
#   'fingers',
#   ';',
#   'groan',
#   'burst',
#   'heaving',
#   'breast',
#   '.'],
#  ['paused',
#   ';',
#   'length',
#   'spoke',
#   ',',
#   'broken',
#   'accents',
#   ':',
#   '“',
#   'unhappy',
#   'man',
#   '!'],
#  ['share', 'madness', '?'],
#  ['drunk', 'also', 'intoxicating', 'draught', '?'],
#  ['hear',
#   ';',
#   'let',
#   'reveal',
#   'tale',
#   ',',
#   'dash',
#   'cup',
#   'lips',
#   '!',
#   '”',
#   'words',
#   ',',
#   'may',
#   'imagine',
#   ',',
#   'strongly',
#   'excited',
#   'curiosity',
#   ';',
#   'paroxysm',
#   'grief',
#   'seized',
#   'stranger',
#   'overcame',
#   'weakened',
#   'powers',
#   ',',
#   'many',
#   'hours',
#   'repose',
#   'tranquil',
#   'conversation',
#   'necessary',
#   'restore',
#   'composure',
#   '.'],
#  ['conquered',
#   'violence',
#   'feelings',
#   ',',
#   'appeared',
#   'despise',
#   'slave',
#   'passion',
#   ';',
#   'quelling',
#   'dark',
#   'tyranny',
#   'despair',
#   ',',
#   'led',
#   'converse',
#   'concerning',
#   'personally',
#   '.'],
#  ['asked', 'history', 'earlier', 'years', '.'],
#  ['tale',
#   'quickly',
#   'told',
#   ',',
#   'awakened',
#   'various',
#   'trains',
#   'reflection',
#   '.'],
#  ['spoke',
#   'desire',
#   'finding',
#   'friend',
#   ',',
#   'thirst',
#   'intimate',
#   'sympathy',
#   'fellow',
#   'mind',
#   'ever',
#   'fallen',
#   'lot',
#   ',',
#   'expressed',
#   'conviction',
#   'man',
#   'could',
#   'boast',
#   'little',
#   'happiness',
#   'enjoy',
#   'blessing',
#   '.'],
#  ['“',
#   'agree',
#   ',',
#   '”',
#   'replied',
#   'stranger',
#   ';',
#   '“',
#   'unfashioned',
#   'creatures',
#   ',',
#   'half',
#   'made',
#   ',',
#   'one',
#   'wiser',
#   ',',
#   'better',
#   ',',
#   'dearer',
#   'ourselves—such',
#   'friend',
#   'ought',
#   'be—do',
#   'lend',
#   'aid',
#   'perfectionate',
#   'weak',
#   'faulty',
#   'natures',
#   '.'],
#  ['friend',
#   ',',
#   'noble',
#   'human',
#   'creatures',
#   ',',
#   'entitled',
#   ',',
#   'therefore',
#   ',',
#   'judge',
#   'respecting',
#   'friendship',
#   '.'],
#  ['hope', ',', 'world', ',', 'cause', 'despair', '.'],
#  ['i—i',
#   'lost',
#   'everything',
#   'begin',
#   'life',
#   'anew.',
#   '”',
#   'said',
#   'countenance',
#   'became',
#   'expressive',
#   'calm',
#   ',',
#   'settled',
#   'grief',
#   'touched',
#   'heart',
#   '.'],
#  ['silent', 'presently', 'retired', 'cabin', '.'],
#  ['even',
#   'broken',
#   'spirit',
#   ',',
#   'one',
#   'feel',
#   'deeply',
#   'beauties',
#   'nature',
#   '.'],
#  ['starry',
#   'sky',
#   ',',
#   'sea',
#   ',',
#   'every',
#   'sight',
#   'afforded',
#   'wonderful',
#   'regions',
#   'seem',
#   'still',
#   'power',
#   'elevating',
#   'soul',
#   'earth',
#   '.'],
#  ['man',
#   'double',
#   'existence',
#   ':',
#   'may',
#   'suffer',
#   'misery',
#   'overwhelmed',
#   'disappointments',
#   ',',
#   'yet',
#   'retired',
#   ',',
#   'like',
#   'celestial',
#   'spirit',
#   'halo',
#   'around',
#   ',',
#   'within',
#   'whose',
#   'circle',
#   'grief',
#   'folly',
#   'ventures',
#   '.'],
#  ['smile', 'enthusiasm', 'express', 'concerning', 'divine', 'wanderer', '?'],
#  ['would', 'saw', '.'],
#  ['tutored',
#   'refined',
#   'books',
#   'retirement',
#   'world',
#   ',',
#   'therefore',
#   'somewhat',
#   'fastidious',
#   ';',
#   'renders',
#   'fit',
#   'appreciate',
#   'extraordinary',
#   'merits',
#   'wonderful',
#   'man',
#   '.'],
#  ['sometimes',
#   'endeavoured',
#   'discover',
#   'quality',
#   'possesses',
#   'elevates',
#   'immeasurably',
#   'person',
#   'ever',
#   'knew',
#   '.'],
#  ['believe',
#   'intuitive',
#   'discernment',
#   ',',
#   'quick',
#   'never-failing',
#   'power',
#   'judgment',
#   ',',
#   'penetration',
#   'causes',
#   'things',
#   ',',
#   'unequalled',
#   'clearness',
#   'precision',
#   ';',
#   'add',
#   'facility',
#   'expression',
#   'voice',
#   'whose',
#   'varied',
#   'intonations',
#   'soul-subduing',
#   'music',
#   '.'],
#  ['august', '19th', ',', '17—', '.'],
#  ['yesterday',
#   'stranger',
#   'said',
#   ',',
#   '“',
#   'may',
#   'easily',
#   'perceive',
#   ',',
#   'captain',
#   'walton',
#   ',',
#   'suffered',
#   'great',
#   'unparalleled',
#   'misfortunes',
#   '.'],
#  ['determined',
#   'one',
#   'time',
#   'memory',
#   'evils',
#   'die',
#   ',',
#   'alter',
#   'determination',
#   '.'],
#  ['seek',
#   'knowledge',
#   'wisdom',
#   ',',
#   ';',
#   'ardently',
#   'hope',
#   'gratification',
#   'wishes',
#   'may',
#   'serpent',
#   'sting',
#   ',',
#   'mine',
#   '.'],
#  ['know',
#   'relation',
#   'disasters',
#   'useful',
#   ';',
#   'yet',
#   ',',
#   'reflect',
#   'pursuing',
#   'course',
#   ',',
#   'exposing',
#   'dangers',
#   'rendered',
#   ',',
#   'imagine',
#   'may',
#   'deduce',
#   'apt',
#   'moral',
#   'tale',
#   ',',
#   'one',
#   'may',
#   'direct',
#   'succeed',
#   'undertaking',
#   'console',
#   'case',
#   'failure',
#   '.'],
#  ['prepare', 'hear', 'occurrences', 'usually', 'deemed', 'marvellous', '.'],
#  ['among',
#   'tamer',
#   'scenes',
#   'nature',
#   'might',
#   'fear',
#   'encounter',
#   'unbelief',
#   ',',
#   'perhaps',
#   'ridicule',
#   ';',
#   'many',
#   'things',
#   'appear',
#   'possible',
#   'wild',
#   'mysterious',
#   'regions',
#   'would',
#   'provoke',
#   'laughter',
#   'unacquainted',
#   'ever-varied',
#   'powers',
#   'nature',
#   ';',
#   'doubt',
#   'tale',
#   'conveys',
#   'series',
#   'internal',
#   'evidence',
#   'truth',
#   'events',
#   'composed.',
#   '”',
#   'may',
#   'easily',
#   'imagine',
#   'much',
#   'gratified',
#   'offered',
#   'communication',
#   ',',
#   'yet',
#   'could',
#   'endure',
#   'renew',
#   'grief',
#   'recital',
#   'misfortunes',
#   '.'],
#  ['felt',
#   'greatest',
#   'eagerness',
#   'hear',
#   'promised',
#   'narrative',
#   ',',
#   'partly',
#   'curiosity',
#   'partly',
#   'strong',
#   'desire',
#   'ameliorate',
#   'fate',
#   'power',
#   '.'],
#  ['expressed', 'feelings', 'answer', '.'],
#  ['“',
#   'thank',
#   ',',
#   '”',
#   'replied',
#   ',',
#   '“',
#   'sympathy',
#   ',',
#   'useless',
#   ';',
#   'fate',
#   'nearly',
#   'fulfilled',
#   '.'],
#  ['wait', 'one', 'event', ',', 'shall', 'repose', 'peace', '.'],
#  ['understand',
#   'feeling',
#   ',',
#   '”',
#   'continued',
#   ',',
#   'perceiving',
#   'wished',
#   'interrupt',
#   ';',
#   '“',
#   'mistaken',
#   ',',
#   'friend',
#   ',',
#   'thus',
#   'allow',
#   'name',
#   ';',
#   'nothing',
#   'alter',
#   'destiny',
#   ';',
#   'listen',
#   'history',
#   ',',
#   'perceive',
#   'irrevocably',
#   'determined.',
#   '”',
#   'told',
#   'would',
#   'commence',
#   'narrative',
#   'next',
#   'day',
#   'leisure',
#   '.'],
#  ['promise', 'drew', 'warmest', 'thanks', '.'],
#  ['resolved',
#   'every',
#   'night',
#   ',',
#   'imperatively',
#   'occupied',
#   'duties',
#   ',',
#   'record',
#   ',',
#   'nearly',
#   'possible',
#   'words',
#   ',',
#   'related',
#   'day',
#   '.'],
#  ['engaged', ',', 'least', 'make', 'notes', '.'],
#  ['manuscript',
#   'doubtless',
#   'afford',
#   'greatest',
#   'pleasure',
#   ';',
#   ',',
#   'know',
#   ',',
#   'hear',
#   'lips—with',
#   'interest',
#   'sympathy',
#   'shall',
#   'read',
#   'future',
#   'day',
#   '!'],
#  ['even',
#   ',',
#   'commence',
#   'task',
#   ',',
#   'full-toned',
#   'voice',
#   'swells',
#   'ears',
#   ';',
#   'lustrous',
#   'eyes',
#   'dwell',
#   'melancholy',
#   'sweetness',
#   ';',
#   'see',
#   'thin',
#   'hand',
#   'raised',
#   'animation',
#   ',',
#   'lineaments',
#   'face',
#   'irradiated',
#   'soul',
#   'within',
#   '.'],
#  ['strange',
#   'harrowing',
#   'must',
#   'story',
#   ',',
#   'frightful',
#   'storm',
#   'embraced',
#   'gallant',
#   'vessel',
#   'course',
#   'wrecked',
#   'it—thus',
#   '!'],
#  ['birth', 'genevese', ',', 'family', 'one', 'distinguished', 'republic', '.'],
#  ['ancestors',
#   'many',
#   'years',
#   'counsellors',
#   'syndics',
#   ',',
#   'father',
#   'filled',
#   'several',
#   'public',
#   'situations',
#   'honour',
#   'reputation',
#   '.'],
#  ['respected',
#   'knew',
#   'integrity',
#   'indefatigable',
#   'attention',
#   'public',
#   'business',
#   '.'],
#  ['passed',
#   'younger',
#   'days',
#   'perpetually',
#   'occupied',
#   'affairs',
#   'country',
#   ';',
#   'variety',
#   'circumstances',
#   'prevented',
#   'marrying',
#   'early',
#   ',',
#   'decline',
#   'life',
#   'became',
#   'husband',
#   'father',
#   'family',
#   '.'],
#  ['circumstances',
#   'marriage',
#   'illustrate',
#   'character',
#   ',',
#   'refrain',
#   'relating',
#   '.'],
#  ['one',
#   'intimate',
#   'friends',
#   'merchant',
#   ',',
#   'flourishing',
#   'state',
#   ',',
#   'fell',
#   ',',
#   'numerous',
#   'mischances',
#   ',',
#   'poverty',
#   '.'],
#  ['man',
#   ',',
#   'whose',
#   'name',
#   'beaufort',
#   ',',
#   'proud',
#   'unbending',
#   'disposition',
#   'could',
#   'bear',
#   'live',
#   'poverty',
#   'oblivion',
#   'country',
#   'formerly',
#   'distinguished',
#   'rank',
#   'magnificence',
#   '.'],
#  ['paid',
#   'debts',
#   ',',
#   'therefore',
#   ',',
#   'honourable',
#   'manner',
#   ',',
#   'retreated',
#   'daughter',
#   'town',
#   'lucerne',
#   ',',
#   'lived',
#   'unknown',
#   'wretchedness',
#   '.'],
#  ['father',
#   'loved',
#   'beaufort',
#   'truest',
#   'friendship',
#   'deeply',
#   'grieved',
#   'retreat',
#   'unfortunate',
#   'circumstances',
#   '.'],
#  ['bitterly',
#   'deplored',
#   'false',
#   'pride',
#   'led',
#   'friend',
#   'conduct',
#   'little',
#   'worthy',
#   'affection',
#   'united',
#   '.'],
#  ['lost',
#   'time',
#   'endeavouring',
#   'seek',
#   ',',
#   'hope',
#   'persuading',
#   'begin',
#   'world',
#   'credit',
#   'assistance',
#   '.'],
#  ['beaufort',
#   'taken',
#   'effectual',
#   'measures',
#   'conceal',
#   ',',
#   'ten',
#   'months',
#   'father',
#   'discovered',
#   'abode',
#   '.'],
#  ['overjoyed',
#   'discovery',
#   ',',
#   'hastened',
#   'house',
#   ',',
#   'situated',
#   'mean',
#   'street',
#   'near',
#   'reuss',
#   '.'],
#  ['entered', ',', 'misery', 'despair', 'alone', 'welcomed', '.'],
#  ['beaufort',
#   'saved',
#   'small',
#   'sum',
#   'money',
#   'wreck',
#   'fortunes',
#   ',',
#   'sufficient',
#   'provide',
#   'sustenance',
#   'months',
#   ',',
#   'meantime',
#   'hoped',
#   'procure',
#   'respectable',
#   'employment',
#   'merchant',
#   '’',
#   'house',
#   '.'],
#  ['interval',
#   ',',
#   'consequently',
#   ',',
#   'spent',
#   'inaction',
#   ';',
#   'grief',
#   'became',
#   'deep',
#   'rankling',
#   'leisure',
#   'reflection',
#   ',',
#   'length',
#   'took',
#   'fast',
#   'hold',
#   'mind',
#   'end',
#   'three',
#   'months',
#   'lay',
#   'bed',
#   'sickness',
#   ',',
#   'incapable',
#   'exertion',
#   '.'],
#  ['daughter',
#   'attended',
#   'greatest',
#   'tenderness',
#   ',',
#   'saw',
#   'despair',
#   'little',
#   'fund',
#   'rapidly',
#   'decreasing',
#   'prospect',
#   'support',
#   '.'],
#  ['caroline',
#   'beaufort',
#   'possessed',
#   'mind',
#   'uncommon',
#   'mould',
#   ',',
#   'courage',
#   'rose',
#   'support',
#   'adversity',
#   '.'],
#  ['procured',
#   'plain',
#   'work',
#   ';',
#   'plaited',
#   'straw',
#   'various',
#   'means',
#   'contrived',
#   'earn',
#   'pittance',
#   'scarcely',
#   'sufficient',
#   'support',
#   'life',
#   '.'],
#  ['several', 'months', 'passed', 'manner', '.'],
#  ['father',
#   'grew',
#   'worse',
#   ';',
#   'time',
#   'entirely',
#   'occupied',
#   'attending',
#   ';',
#   'means',
#   'subsistence',
#   'decreased',
#   ';',
#   'tenth',
#   'month',
#   'father',
#   'died',
#   'arms',
#   ',',
#   'leaving',
#   'orphan',
#   'beggar',
#   '.'],
#  ['last',
#   'blow',
#   'overcame',
#   ',',
#   'knelt',
#   'beaufort',
#   '’',
#   'coffin',
#   'weeping',
#   'bitterly',
#   ',',
#   'father',
#   'entered',
#   'chamber',
#   '.'],
#  ['came',
#   'like',
#   'protecting',
#   'spirit',
#   'poor',
#   'girl',
#   ',',
#   'committed',
#   'care',
#   ';',
#   'interment',
#   'friend',
#   'conducted',
#   'geneva',
#   'placed',
#   'protection',
#   'relation',
#   '.'],
#  ['two', 'years', 'event', 'caroline', 'became', 'wife', '.'],
#  ['considerable',
#   'difference',
#   'ages',
#   'parents',
#   ',',
#   'circumstance',
#   'seemed',
#   'unite',
#   'closer',
#   'bonds',
#   'devoted',
#   'affection',
#   '.'],
#  ['sense',
#   'justice',
#   'father',
#   '’',
#   'upright',
#   'mind',
#   'rendered',
#   'necessary',
#   'approve',
#   'highly',
#   'love',
#   'strongly',
#   '.'],
#  ['perhaps',
#   'former',
#   'years',
#   'suffered',
#   'late-discovered',
#   'unworthiness',
#   'one',
#   'beloved',
#   'disposed',
#   'set',
#   'greater',
#   'value',
#   'tried',
#   'worth',
#   '.'],
#  ['show',
#   'gratitude',
#   'worship',
#   'attachment',
#   'mother',
#   ',',
#   'differing',
#   'wholly',
#   'doting',
#   'fondness',
#   'age',
#   ',',
#   'inspired',
#   'reverence',
#   'virtues',
#   'desire',
#   'means',
#   ',',
#   'degree',
#   ',',
#   'recompensing',
#   'sorrows',
#   'endured',
#   ',',
#   'gave',
#   'inexpressible',
#   'grace',
#   'behaviour',
#   '.'],
#  ['everything', 'made', 'yield', 'wishes', 'convenience', '.'],
#  ['strove',
#   'shelter',
#   ',',
#   'fair',
#   'exotic',
#   'sheltered',
#   'gardener',
#   ',',
#   'every',
#   'rougher',
#   'wind',
#   'surround',
#   'could',
#   'tend',
#   'excite',
#   'pleasurable',
#   'emotion',
#   'soft',
#   'benevolent',
#   'mind',
#   '.'],
#  ['health',
#   ',',
#   'even',
#   'tranquillity',
#   'hitherto',
#   'constant',
#   'spirit',
#   ',',
#   'shaken',
#   'gone',
#   '.'],
#  ['two',
#   'years',
#   'elapsed',
#   'previous',
#   'marriage',
#   'father',
#   'gradually',
#   'relinquished',
#   'public',
#   'functions',
#   ';',
#   'immediately',
#   'union',
#   'sought',
#   'pleasant',
#   'climate',
#   'italy',
#   ',',
#   'change',
#   'scene',
#   'interest',
#   'attendant',
#   'tour',
#   'land',
#   'wonders',
#   ',',
#   'restorative',
#   'weakened',
#   'frame',
#   '.'],
#  ['italy', 'visited', 'germany', 'france', '.'],
#  [',',
#   'eldest',
#   'child',
#   ',',
#   'born',
#   'naples',
#   ',',
#   'infant',
#   'accompanied',
#   'rambles',
#   '.'],
#  ['remained', 'several', 'years', 'child', '.'],
#  ['much',
#   'attached',
#   ',',
#   'seemed',
#   'draw',
#   'inexhaustible',
#   'stores',
#   'affection',
#   'mine',
#   'love',
#   'bestow',
#   'upon',
#   '.'],
#  ['mother',
#   '’',
#   'tender',
#   'caresses',
#   'father',
#   '’',
#   'smile',
#   'benevolent',
#   'pleasure',
#   'regarding',
#   'first',
#   'recollections',
#   '.'],
#  ['plaything',
#   'idol',
#   ',',
#   'something',
#   'better—their',
#   'child',
#   ',',
#   'innocent',
#   'helpless',
#   'creature',
#   'bestowed',
#   'heaven',
#   ',',
#   'bring',
#   'good',
#   ',',
#   'whose',
#   'future',
#   'lot',
#   'hands',
#   'direct',
#   'happiness',
#   'misery',
#   ',',
#   'according',
#   'fulfilled',
#   'duties',
#   'towards',
#   '.'],
#  ['deep',
#   'consciousness',
#   'owed',
#   'towards',
#   'given',
#   'life',
#   ',',
#   'added',
#   'active',
#   'spirit',
#   'tenderness',
#   'animated',
#   ',',
#   'may',
#   'imagined',
#   'every',
#   'hour',
#   'infant',
#   'life',
#   'received',
#   'lesson',
#   'patience',
#   ',',
#   'charity',
#   ',',
#   'self-control',
#   ',',
#   'guided',
#   'silken',
#   'cord',
#   'seemed',
#   'one',
#   'train',
#   'enjoyment',
#   '.'],
#  ['long', 'time', 'care', '.'],
#  ['mother',
#   'much',
#   'desired',
#   'daughter',
#   ',',
#   'continued',
#   'single',
#   'offspring',
#   '.'],
#  ['five',
#   'years',
#   'old',
#   ',',
#   'making',
#   'excursion',
#   'beyond',
#   'frontiers',
#   'italy',
#   ',',
#   'passed',
#   'week',
#   'shores',
#   'lake',
#   'como',
#   '.'],
#  ['benevolent',
#   'disposition',
#   'often',
#   'made',
#   'enter',
#   'cottages',
#   'poor',
#   '.'],
#  [',',
#   'mother',
#   ',',
#   'duty',
#   ';',
#   'necessity',
#   ',',
#   'passion—remembering',
#   'suffered',
#   ',',
#   'relieved—for',
#   'act',
#   'turn',
#   'guardian',
#   'angel',
#   'afflicted',
#   '.'],
#  ['one',
#   'walks',
#   'poor',
#   'cot',
#   'foldings',
#   'vale',
#   'attracted',
#   'notice',
#   'singularly',
#   'disconsolate',
#   ',',
#   'number',
#   'half-clothed',
#   'children',
#   'gathered',
#   'spoke',
#   'penury',
#   'worst',
#   'shape',
#   '.'],
#  ['one',
#   'day',
#   ',',
#   'father',
#   'gone',
#   'milan',
#   ',',
#   'mother',
#   ',',
#   'accompanied',
#   ',',
#   'visited',
#   'abode',
#   '.'],
#  ['found',
#   'peasant',
#   'wife',
#   ',',
#   'hard',
#   'working',
#   ',',
#   'bent',
#   'care',
#   'labour',
#   ',',
#   'distributing',
#   'scanty',
#   'meal',
#   'five',
#   'hungry',
#   'babes',
#   '.'],
#  ['among', 'one', 'attracted', 'mother', 'far', 'rest', '.'],
#  ['appeared', 'different', 'stock', '.'],
#  ['four',
#   'others',
#   'dark-eyed',
#   ',',
#   'hardy',
#   'little',
#   'vagrants',
#   ';',
#   'child',
#   'thin',
#   'fair',
#   '.'],
#  ['hair',
#   'brightest',
#   'living',
#   'gold',
#   ',',
#   'despite',
#   'poverty',
#   'clothing',
#   ',',
#   'seemed',
#   'set',
#   'crown',
#   'distinction',
#   'head',
#   '.'],
#  ['brow',
#   'clear',
#   'ample',
#   ',',
#   'blue',
#   'eyes',
#   'cloudless',
#   ',',
#   'lips',
#   'moulding',
#   'face',
#   'expressive',
#   'sensibility',
#   'sweetness',
#   'none',
#   'could',
#   'behold',
#   'without',
#   'looking',
#   'distinct',
#   'species',
#   ',',
#   'heaven-sent',
#   ',',
#   'bearing',
#   'celestial',
#   'stamp',
#   'features',
#   '.'],
#  ['peasant',
#   'woman',
#   ',',
#   'perceiving',
#   'mother',
#   'fixed',
#   'eyes',
#   'wonder',
#   'admiration',
#   'lovely',
#   'girl',
#   ',',
#   'eagerly',
#   'communicated',
#   'history',
#   '.'],
#  ['child', ',', 'daughter', 'milanese', 'nobleman', '.'],
#  ['mother', 'german', 'died', 'giving', 'birth', '.'],
#  ['infant', 'placed', 'good', 'people', 'nurse', ':', 'better', '.'],
#  ['long', 'married', ',', 'eldest', 'child', 'born', '.'],
#  ['father',
#   'charge',
#   'one',
#   'italians',
#   'nursed',
#   'memory',
#   'antique',
#   'glory',
#   'italy—one',
#   'among',
#   'schiavi',
#   'ognor',
#   'frementi',
#   ',',
#   'exerted',
#   'obtain',
#   'liberty',
#   'country',
#   '.'],
#  ['became', 'victim', 'weakness', '.'],
#  ['whether', 'died', 'still', 'lingered', 'dungeons', 'austria', 'known', '.'],
#  ['property', 'confiscated', ';', 'child', 'became', 'orphan', 'beggar', '.'],
#  ['continued',
#   'foster',
#   'parents',
#   'bloomed',
#   'rude',
#   'abode',
#   ',',
#   'fairer',
#   'garden',
#   'rose',
#   'among',
#   'dark-leaved',
#   'brambles',
#   '.'],
#  ['father',
#   'returned',
#   'milan',
#   ',',
#   'found',
#   'playing',
#   'hall',
#   'villa',
#   'child',
#   'fairer',
#   'pictured',
#   'cherub—a',
#   'creature',
#   'seemed',
#   'shed',
#   'radiance',
#   'looks',
#   'whose',
#   'form',
#   'motions',
#   'lighter',
#   'chamois',
#   'hills',
#   '.'],
#  ['apparition', 'soon', 'explained', '.'],
#  ['permission',
#   'mother',
#   'prevailed',
#   'rustic',
#   'guardians',
#   'yield',
#   'charge',
#   '.'],
#  ['fond', 'sweet', 'orphan', '.'],
#  ['presence',
#   'seemed',
#   'blessing',
#   ',',
#   'would',
#   'unfair',
#   'keep',
#   'poverty',
#   'want',
#   'providence',
#   'afforded',
#   'powerful',
#   'protection',
#   '.'],
#  ['consulted',
#   'village',
#   'priest',
#   ',',
#   'result',
#   'elizabeth',
#   'lavenza',
#   'became',
#   'inmate',
#   'parents',
#   '’',
#   'house—my',
#   'sister—the',
#   'beautiful',
#   'adored',
#   'companion',
#   'occupations',
#   'pleasures',
#   '.'],
#  ['everyone', 'loved', 'elizabeth', '.'],
#  ['passionate',
#   'almost',
#   'reverential',
#   'attachment',
#   'regarded',
#   'became',
#   ',',
#   'shared',
#   ',',
#   'pride',
#   'delight',
#   '.'],
#  ['evening',
#   'previous',
#   'brought',
#   'home',
#   ',',
#   'mother',
#   'said',
#   'playfully',
#   ',',
#   '“',
#   'pretty',
#   'present',
#   'victor—tomorrow',
#   'shall',
#   'it.',
#   '”',
#   ',',
#   'morrow',
#   ',',
#   'presented',
#   'elizabeth',
#   'promised',
#   'gift',
#   ',',
#   ',',
#   'childish',
#   'seriousness',
#   ',',
#   'interpreted',
#   'words',
#   'literally',
#   'looked',
#   'upon',
#   'elizabeth',
#   'mine—mine',
#   'protect',
#   ',',
#   'love',
#   ',',
#   'cherish',
#   '.'],
#  ['praises', 'bestowed', 'received', 'made', 'possession', '.'],
#  ['called', 'familiarly', 'name', 'cousin', '.'],
#  ['word',
#   ',',
#   'expression',
#   'could',
#   'body',
#   'forth',
#   'kind',
#   'relation',
#   'stood',
#   'me—my',
#   'sister',
#   ',',
#   'since',
#   'till',
#   'death',
# ...
#  ['told',
#   'servants',
#   'disturb',
#   'family',
#   ',',
#   'went',
#   'library',
#   'attend',
#   'usual',
#   'hour',
#   'rising',
#   '.'],
#  ['six',
#   'years',
#   'elapsed',
#   ',',
#   'passed',
#   'dream',
#   'one',
#   'indelible',
#   'trace',
#   ',',
#   'stood',
#   'place',
#   'last',
#   'embraced',
#   'father',
#   'departure',
#   'ingolstadt',
#   '.'],
#  ['beloved', 'venerable', 'parent', '!'],
#  ['still', 'remained', '.'],
#  ['gazed', 'picture', 'mother', ',', 'stood', 'mantel-piece', '.'],
#  ['historical',
#   'subject',
#   ',',
#   'painted',
#   'father',
#   '’',
#   'desire',
#   ',',
#   'represented',
#   'caroline',
#   'beaufort',
#   'agony',
#   'despair',
#   ',',
#   'kneeling',
#   'coffin',
#   'dead',
#   'father',
#   '.'],
#  ['garb',
#   'rustic',
#   ',',
#   'cheek',
#   'pale',
#   ';',
#   'air',
#   'dignity',
#   'beauty',
#   ',',
#   'hardly',
#   'permitted',
#   'sentiment',
#   'pity',
#   '.'],
#  ['picture',
#   'miniature',
#   'william',
#   ';',
#   'tears',
#   'flowed',
#   'looked',
#   'upon',
#   '.'],
#  ['thus',
#   'engaged',
#   ',',
#   'ernest',
#   'entered',
#   ':',
#   'heard',
#   'arrive',
#   ',',
#   'hastened',
#   'welcome',
#   ':',
#   '“',
#   'welcome',
#   ',',
#   'dearest',
#   'victor',
#   ',',
#   '”',
#   'said',
#   '.'],
#  ['“', 'ah', '!'],
#  ['wish',
#   'come',
#   'three',
#   'months',
#   'ago',
#   ',',
#   'would',
#   'found',
#   'us',
#   'joyous',
#   'delighted',
#   '.'],
#  ['come',
#   'us',
#   'share',
#   'misery',
#   'nothing',
#   'alleviate',
#   ';',
#   'yet',
#   'presence',
#   ',',
#   'hope',
#   ',',
#   'revive',
#   'father',
#   ',',
#   'seems',
#   'sinking',
#   'misfortune',
#   ';',
#   'persuasions',
#   'induce',
#   'poor',
#   'elizabeth',
#   'cease',
#   'vain',
#   'tormenting',
#   'self-accusations.—poor',
#   'william',
#   '!'],
#  ['darling',
#   'pride',
#   '!',
#   '”',
#   'tears',
#   ',',
#   'unrestrained',
#   ',',
#   'fell',
#   'brother',
#   '’',
#   'eyes',
#   ';',
#   'sense',
#   'mortal',
#   'agony',
#   'crept',
#   'frame',
#   '.'],
#  [',',
#   'imagined',
#   'wretchedness',
#   'desolated',
#   'home',
#   ';',
#   'reality',
#   'came',
#   'new',
#   ',',
#   'less',
#   'terrible',
#   ',',
#   'disaster',
#   '.'],
#  ['tried',
#   'calm',
#   'ernest',
#   ';',
#   'enquired',
#   'minutely',
#   'concerning',
#   'father',
#   ',',
#   'named',
#   'cousin',
#   '.'],
#  ['“',
#   ',',
#   '”',
#   'said',
#   'ernest',
#   ',',
#   '“',
#   'requires',
#   'consolation',
#   ';',
#   'accused',
#   'caused',
#   'death',
#   'brother',
#   ',',
#   'made',
#   'wretched',
#   '.'],
#  ['since', 'murderer', 'discovered—', '”', '“', 'murderer', 'discovered', '!'],
#  ['good', 'god', '!'],
#  ['?'],
#  ['could', 'attempt', 'pursue', '?'],
#  ['impossible',
#   ';',
#   'one',
#   'might',
#   'well',
#   'try',
#   'overtake',
#   'winds',
#   ',',
#   'confine',
#   'mountain-stream',
#   'straw',
#   '.'],
#  ['saw',
#   ';',
#   'free',
#   'last',
#   'night',
#   '!',
#   '”',
#   '“',
#   'know',
#   'mean',
#   ',',
#   '”',
#   'replied',
#   'brother',
#   ',',
#   'accents',
#   'wonder',
#   ',',
#   '“',
#   'us',
#   'discovery',
#   'made',
#   'completes',
#   'misery',
#   '.'],
#  ['one',
#   'would',
#   'believe',
#   'first',
#   ';',
#   'even',
#   'elizabeth',
#   'convinced',
#   ',',
#   'notwithstanding',
#   'evidence',
#   '.'],
#  ['indeed',
#   ',',
#   'would',
#   'credit',
#   'justine',
#   'moritz',
#   ',',
#   'amiable',
#   ',',
#   'fond',
#   'family',
#   ',',
#   'could',
#   'suddenly',
#   'become',
#   'capable',
#   'frightful',
#   ',',
#   'appalling',
#   'crime',
#   '?',
#   '”',
#   '“',
#   'justine',
#   'moritz',
#   '!'],
#  ['poor', ',', 'poor', 'girl', ',', 'accused', '?'],
#  ['wrongfully',
#   ';',
#   'every',
#   'one',
#   'knows',
#   ';',
#   'one',
#   'believes',
#   ',',
#   'surely',
#   ',',
#   'ernest',
#   '?',
#   '”',
#   '“',
#   'one',
#   'first',
#   ';',
#   'several',
#   'circumstances',
#   'came',
#   ',',
#   'almost',
#   'forced',
#   'conviction',
#   'upon',
#   'us',
#   ';',
#   'behaviour',
#   'confused',
#   ',',
#   'add',
#   'evidence',
#   'facts',
#   'weight',
#   ',',
#   'fear',
#   ',',
#   'leaves',
#   'hope',
#   'doubt',
#   '.'],
#  ['tried',
#   'today',
#   ',',
#   'hear',
#   'all.',
#   '”',
#   'related',
#   ',',
#   'morning',
#   'murder',
#   'poor',
#   'william',
#   'discovered',
#   ',',
#   'justine',
#   'taken',
#   'ill',
#   ',',
#   'confined',
#   'bed',
#   'several',
#   'days',
#   '.'],
#  ['interval',
#   ',',
#   'one',
#   'servants',
#   ',',
#   'happening',
#   'examine',
#   'apparel',
#   'worn',
#   'night',
#   'murder',
#   ',',
#   'discovered',
#   'pocket',
#   'picture',
#   'mother',
#   ',',
#   'judged',
#   'temptation',
#   'murderer',
#   '.'],
#  ['servant',
#   'instantly',
#   'showed',
#   'one',
#   'others',
#   ',',
#   ',',
#   'without',
#   'saying',
#   'word',
#   'family',
#   ',',
#   'went',
#   'magistrate',
#   ';',
#   ',',
#   'upon',
#   'deposition',
#   ',',
#   'justine',
#   'apprehended',
#   '.'],
#  ['charged',
#   'fact',
#   ',',
#   'poor',
#   'girl',
#   'confirmed',
#   'suspicion',
#   'great',
#   'measure',
#   'extreme',
#   'confusion',
#   'manner',
#   '.'],
#  ['strange',
#   'tale',
#   ',',
#   'shake',
#   'faith',
#   ';',
#   'replied',
#   'earnestly',
#   ',',
#   '“',
#   'mistaken',
#   ';',
#   'know',
#   'murderer',
#   '.'],
#  ['justine',
#   ',',
#   'poor',
#   ',',
#   'good',
#   'justine',
#   ',',
#   'innocent.',
#   '”',
#   'instant',
#   'father',
#   'entered',
#   '.'],
#  ['saw',
#   'unhappiness',
#   'deeply',
#   'impressed',
#   'countenance',
#   ',',
#   'endeavoured',
#   'welcome',
#   'cheerfully',
#   ';',
#   ',',
#   'exchanged',
#   'mournful',
#   'greeting',
#   ',',
#   'would',
#   'introduced',
#   'topic',
#   'disaster',
#   ',',
#   'ernest',
#   'exclaimed',
#   ',',
#   '“',
#   'good',
#   'god',
#   ',',
#   'papa',
#   '!'],
#  ['victor',
#   'says',
#   'knows',
#   'murderer',
#   'poor',
#   'william.',
#   '”',
#   '“',
#   'also',
#   ',',
#   'unfortunately',
#   ',',
#   '”',
#   'replied',
#   'father',
#   ',',
#   '“',
#   'indeed',
#   'rather',
#   'ever',
#   'ignorant',
#   'discovered',
#   'much',
#   'depravity',
#   'ungratitude',
#   'one',
#   'valued',
#   'highly.',
#   '”',
#   '“',
#   'dear',
#   'father',
#   ',',
#   'mistaken',
#   ';',
#   'justine',
#   'innocent.',
#   '”',
#   '“',
#   ',',
#   'god',
#   'forbid',
#   'suffer',
#   'guilty',
#   '.'],
#  ['tried',
#   'today',
#   ',',
#   'hope',
#   ',',
#   'sincerely',
#   'hope',
#   ',',
#   'acquitted.',
#   '”',
#   'speech',
#   'calmed',
#   '.'],
#  ['firmly',
#   'convinced',
#   'mind',
#   'justine',
#   ',',
#   'indeed',
#   'every',
#   'human',
#   ',',
#   'guiltless',
#   'murder',
#   '.'],
#  ['fear',
#   ',',
#   'therefore',
#   ',',
#   'circumstantial',
#   'evidence',
#   'could',
#   'brought',
#   'forward',
#   'strong',
#   'enough',
#   'convict',
#   '.'],
#  ['tale',
#   'one',
#   'announce',
#   'publicly',
#   ';',
#   'astounding',
#   'horror',
#   'would',
#   'looked',
#   'upon',
#   'madness',
#   'vulgar',
#   '.'],
#  ['one',
#   'indeed',
#   'exist',
#   ',',
#   'except',
#   ',',
#   'creator',
#   ',',
#   'would',
#   'believe',
#   ',',
#   'unless',
#   'senses',
#   'convinced',
#   ',',
#   'existence',
#   'living',
#   'monument',
#   'presumption',
#   'rash',
#   'ignorance',
#   'let',
#   'loose',
#   'upon',
#   'world',
#   '?'],
#  ['soon', 'joined', 'elizabeth', '.'],
#  ['time',
#   'altered',
#   'since',
#   'last',
#   'beheld',
#   ';',
#   'endowed',
#   'loveliness',
#   'surpassing',
#   'beauty',
#   'childish',
#   'years',
#   '.'],
#  ['candour',
#   ',',
#   'vivacity',
#   ',',
#   'allied',
#   'expression',
#   'full',
#   'sensibility',
#   'intellect',
#   '.'],
#  ['welcomed', 'greatest', 'affection', '.'],
#  ['“',
#   'arrival',
#   ',',
#   'dear',
#   'cousin',
#   ',',
#   '”',
#   'said',
#   ',',
#   '“',
#   'fills',
#   'hope',
#   '.'],
#  ['perhaps', 'find', 'means', 'justify', 'poor', 'guiltless', 'justine', '.'],
#  ['alas', '!'],
#  ['safe', ',', 'convicted', 'crime', '?'],
#  ['rely', 'innocence', 'certainly', 'upon', '.'],
#  ['misfortune',
#   'doubly',
#   'hard',
#   'us',
#   ';',
#   'lost',
#   'lovely',
#   'darling',
#   'boy',
#   ',',
#   'poor',
#   'girl',
#   ',',
#   'sincerely',
#   'love',
#   ',',
#   'torn',
#   'away',
#   'even',
#   'worse',
#   'fate',
#   '.'],
#  ['condemned', ',', 'never', 'shall', 'know', 'joy', '.'],
#  [',',
#   'sure',
#   ';',
#   'shall',
#   'happy',
#   ',',
#   'even',
#   'sad',
#   'death',
#   'little',
#   'william.',
#   '”',
#   '“',
#   'innocent',
#   ',',
#   'elizabeth',
#   ',',
#   '”',
#   'said',
#   ',',
#   '“',
#   'shall',
#   'proved',
#   ';',
#   'fear',
#   'nothing',
#   ',',
#   'let',
#   'spirits',
#   'cheered',
#   'assurance',
#   'acquittal.',
#   '”',
#   '“',
#   'kind',
#   'generous',
#   '!'],
#  ['every',
#   'one',
#   'else',
#   'believes',
#   'guilt',
#   ',',
#   'made',
#   'wretched',
#   ',',
#   'knew',
#   'impossible',
#   ':',
#   'see',
#   'every',
#   'one',
#   'else',
#   'prejudiced',
#   'deadly',
#   'manner',
#   'rendered',
#   'hopeless',
#   'despairing.',
#   '”',
#   'wept',
#   '.'],
#  ['“',
#   'dearest',
#   'niece',
#   ',',
#   '”',
#   'said',
#   'father',
#   ',',
#   '“',
#   'dry',
#   'tears',
#   '.'],
#  [',',
#   'believe',
#   ',',
#   'innocent',
#   ',',
#   'rely',
#   'justice',
#   'laws',
#   ',',
#   'activity',
#   'shall',
#   'prevent',
#   'slightest',
#   'shadow',
#   'partiality.',
#   '”',
#   'passed',
#   'sad',
#   'hours',
#   'eleven',
#   '’',
#   'clock',
#   ',',
#   'trial',
#   'commence',
#   '.'],
#  ['father',
#   'rest',
#   'family',
#   'obliged',
#   'attend',
#   'witnesses',
#   ',',
#   'accompanied',
#   'court',
#   '.'],
#  ['whole',
#   'wretched',
#   'mockery',
#   'justice',
#   'suffered',
#   'living',
#   'torture',
#   '.'],
#  ['decided',
#   'whether',
#   'result',
#   'curiosity',
#   'lawless',
#   'devices',
#   'would',
#   'cause',
#   'death',
#   'two',
#   'fellow',
#   'beings',
#   ':',
#   'one',
#   'smiling',
#   'babe',
#   'full',
#   'innocence',
#   'joy',
#   ',',
#   'far',
#   'dreadfully',
#   'murdered',
#   ',',
#   'every',
#   'aggravation',
#   'infamy',
#   'could',
#   'make',
#   'murder',
#   'memorable',
#   'horror',
#   '.'],
#  ['justine',
#   'also',
#   'girl',
#   'merit',
#   'possessed',
#   'qualities',
#   'promised',
#   'render',
#   'life',
#   'happy',
#   ';',
#   'obliterated',
#   'ignominious',
#   'grave',
#   ',',
#   'cause',
#   '!'],
#  ['thousand',
#   'times',
#   'rather',
#   'would',
#   'confessed',
#   'guilty',
#   'crime',
#   'ascribed',
#   'justine',
#   ',',
#   'absent',
#   'committed',
#   ',',
#   'declaration',
#   'would',
#   'considered',
#   'ravings',
#   'madman',
#   'would',
#   'exculpated',
#   'suffered',
#   '.'],
#  ['appearance', 'justine', 'calm', '.'],
#  ['dressed',
#   'mourning',
#   ',',
#   'countenance',
#   ',',
#   'always',
#   'engaging',
#   ',',
#   'rendered',
#   ',',
#   'solemnity',
#   'feelings',
#   ',',
#   'exquisitely',
#   'beautiful',
#   '.'],
#  ['yet',
#   'appeared',
#   'confident',
#   'innocence',
#   'tremble',
#   ',',
#   'although',
#   'gazed',
#   'execrated',
#   'thousands',
#   ',',
#   'kindness',
#   'beauty',
#   'might',
#   'otherwise',
#   'excited',
#   'obliterated',
#   'minds',
#   'spectators',
#   'imagination',
#   'enormity',
#   'supposed',
#   'committed',
#   '.'],
#  ['tranquil',
#   ',',
#   'yet',
#   'tranquillity',
#   'evidently',
#   'constrained',
#   ';',
#   'confusion',
#   'adduced',
#   'proof',
#   'guilt',
#   ',',
#   'worked',
#   'mind',
#   'appearance',
#   'courage',
#   '.'],
#  ['entered',
#   'court',
#   'threw',
#   'eyes',
#   'round',
#   'quickly',
#   'discovered',
#   'seated',
#   '.'],
#  ['tear',
#   'seemed',
#   'dim',
#   'eye',
#   'saw',
#   'us',
#   ',',
#   'quickly',
#   'recovered',
#   ',',
#   'look',
#   'sorrowful',
#   'affection',
#   'seemed',
#   'attest',
#   'utter',
#   'guiltlessness',
#   '.'],
#  ['trial',
#   'began',
#   ',',
#   'advocate',
#   'stated',
#   'charge',
#   ',',
#   'several',
#   'witnesses',
#   'called',
#   '.'],
#  ['several',
#   'strange',
#   'facts',
#   'combined',
#   ',',
#   'might',
#   'staggered',
#   'anyone',
#   'proof',
#   'innocence',
#   '.'],
#  ['whole',
#   'night',
#   'murder',
#   'committed',
#   'towards',
#   'morning',
#   'perceived',
#   'market-woman',
#   'far',
#   'spot',
#   'body',
#   'murdered',
#   'child',
#   'afterwards',
#   'found',
#   '.'],
#  ['woman',
#   'asked',
#   ',',
#   'looked',
#   'strangely',
#   'returned',
#   'confused',
#   'unintelligible',
#   'answer',
#   '.'],
#  ['returned',
#   'house',
#   'eight',
#   '’',
#   'clock',
#   ',',
#   'one',
#   'inquired',
#   'passed',
#   'night',
#   ',',
#   'replied',
#   'looking',
#   'child',
#   'demanded',
#   'earnestly',
#   'anything',
#   'heard',
#   'concerning',
#   '.'],
#  ['shown',
#   'body',
#   ',',
#   'fell',
#   'violent',
#   'hysterics',
#   'kept',
#   'bed',
#   'several',
#   'days',
#   '.'],
#  ['picture',
#   'produced',
#   'servant',
#   'found',
#   'pocket',
#   ';',
#   'elizabeth',
#   ',',
#   'faltering',
#   'voice',
#   ',',
#   'proved',
#   ',',
#   'hour',
#   'child',
#   'missed',
#   ',',
#   'placed',
#   'round',
#   'neck',
#   ',',
#   'murmur',
#   'horror',
#   'indignation',
#   'filled',
#   'court',
#   '.'],
#  ['justine', 'called', 'defence', '.'],
#  ['trial', 'proceeded', ',', 'countenance', 'altered', '.'],
#  ['surprise', ',', 'horror', ',', 'misery', 'strongly', 'expressed', '.'],
#  ['sometimes',
#   'struggled',
#   'tears',
#   ',',
#   'desired',
#   'plead',
#   ',',
#   'collected',
#   'powers',
#   'spoke',
#   'audible',
#   'although',
#   'variable',
#   'voice',
#   '.'],
#  ['“',
#   'god',
#   'knows',
#   ',',
#   '”',
#   'said',
#   ',',
#   '“',
#   'entirely',
#   'innocent',
#   '.'],
#  ['pretend',
#   'protestations',
#   'acquit',
#   ';',
#   'rest',
#   'innocence',
#   'plain',
#   'simple',
#   'explanation',
#   'facts',
#   'adduced',
#   ',',
#   'hope',
#   'character',
#   'always',
#   'borne',
#   'incline',
#   'judges',
#   'favourable',
#   'interpretation',
#   'circumstance',
#   'appears',
#   'doubtful',
#   'suspicious.',
#   '”',
#   'related',
#   ',',
#   'permission',
#   'elizabeth',
#   ',',
#   'passed',
#   'evening',
#   'night',
#   'murder',
#   'committed',
#   'house',
#   'aunt',
#   'chêne',
#   ',',
#   'village',
#   'situated',
#   'league',
#   'geneva',
#   '.'],
#  ['return',
#   ',',
#   'nine',
#   '’',
#   'clock',
#   ',',
#   'met',
#   'man',
#   'asked',
#   'seen',
#   'anything',
#   'child',
#   'lost',
#   '.'],
#  ['alarmed',
#   'account',
#   'passed',
#   'several',
#   'hours',
#   'looking',
#   ',',
#   'gates',
#   'geneva',
#   'shut',
#   ',',
#   'forced',
#   'remain',
#   'several',
#   'hours',
#   'night',
#   'barn',
#   'belonging',
#   'cottage',
#   ',',
#   'unwilling',
#   'call',
#   'inhabitants',
#   ',',
#   'well',
#   'known',
#   '.'],
#  ['night',
#   'spent',
#   'watching',
#   ';',
#   'towards',
#   'morning',
#   'believed',
#   'slept',
#   'minutes',
#   ';',
#   'steps',
#   'disturbed',
#   ',',
#   'awoke',
#   '.'],
#  ['dawn',
#   ',',
#   'quitted',
#   'asylum',
#   ',',
#   'might',
#   'endeavour',
#   'find',
#   'brother',
#   '.'],
#  ['gone', 'near', 'spot', 'body', 'lay', ',', 'without', 'knowledge', '.'],
#  ['bewildered',
#   'questioned',
#   'market-woman',
#   'surprising',
#   ',',
#   'since',
#   'passed',
#   'sleepless',
#   'night',
#   'fate',
#   'poor',
#   'william',
#   'yet',
#   'uncertain',
#   '.'],
#  ['concerning', 'picture', 'could', 'give', 'account', '.'],
#  ['“',
#   'know',
#   ',',
#   '”',
#   'continued',
#   'unhappy',
#   'victim',
#   ',',
#   '“',
#   'heavily',
#   'fatally',
#   'one',
#   'circumstance',
#   'weighs',
#   ',',
#   'power',
#   'explaining',
#   ';',
#   'expressed',
#   'utter',
#   'ignorance',
#   ',',
#   'left',
#   'conjecture',
#   'concerning',
#   'probabilities',
#   'might',
#   'placed',
#   'pocket',
#   '.'],
#  ['also', 'checked', '.'],
#  ['believe',
#   'enemy',
#   'earth',
#   ',',
#   'none',
#   'surely',
#   'would',
#   'wicked',
#   'destroy',
#   'wantonly',
#   '.'],
#  ['murderer', 'place', '?'],
#  ['know',
#   'opportunity',
#   'afforded',
#   ';',
#   ',',
#   ',',
#   'stolen',
#   'jewel',
#   ',',
#   'part',
#   'soon',
#   '?'],
#  ['“',
#   'commit',
#   'cause',
#   'justice',
#   'judges',
#   ',',
#   'yet',
#   'see',
#   'room',
#   'hope',
#   '.'],
#  ['beg',
#   'permission',
#   'witnesses',
#   'examined',
#   'concerning',
#   'character',
#   ',',
#   'testimony',
#   'shall',
#   'overweigh',
#   'supposed',
#   'guilt',
#   ',',
#   'must',
#   'condemned',
#   ',',
#   'although',
#   'would',
#   'pledge',
#   'salvation',
#   'innocence.',
#   '”',
#   'several',
#   'witnesses',
#   'called',
#   'known',
#   'many',
#   'years',
#   ',',
#   'spoke',
#   'well',
#   ';',
#   'fear',
#   'hatred',
#   'crime',
#   'supposed',
#   'guilty',
#   'rendered',
#   'timorous',
#   'unwilling',
#   'come',
#   'forward',
#   '.'],
#  ['elizabeth',
#   'saw',
#   'even',
#   'last',
#   'resource',
#   ',',
#   'excellent',
#   'dispositions',
#   'irreproachable',
#   'conduct',
#   ',',
#   'fail',
#   'accused',
#   ',',
#   ',',
#   'although',
#   'violently',
#   'agitated',
#   ',',
#   'desired',
#   'permission',
#   'address',
#   'court',
#   '.'],
#  ['“',
#   ',',
#   '”',
#   'said',
#   ',',
#   '“',
#   'cousin',
#   'unhappy',
#   'child',
#   'murdered',
#   ',',
#   'rather',
#   'sister',
#   ',',
#   'educated',
#   'lived',
#   'parents',
#   'ever',
#   'since',
#   'even',
#   'long',
#   'birth',
#   '.'],
#  ['may',
#   'therefore',
#   'judged',
#   'indecent',
#   'come',
#   'forward',
#   'occasion',
#   ',',
#   'see',
#   'fellow',
#   'creature',
#   'perish',
#   'cowardice',
#   'pretended',
#   'friends',
#   ',',
#   'wish',
#   'allowed',
#   'speak',
#   ',',
#   'may',
#   'say',
#   'know',
#   'character',
#   '.'],
#  ...]

# %%
len(filtered_data)
# Out:
# 3083

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',\
    level=logging.INFO)

# Set values for various parameters
num_features = 300    # Word vector dimensionality                      
min_word_count = 10   # Minimum word count                        
num_workers = -1      # Number of threads to run in parallel
context = 10          # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words

# Initialize and train the model (this will take some time)
from gensim.models import word2vec
print ("Training model...")
model = word2vec.Word2Vec(filtered_data, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling)
# Out:
# 2019-11-06 08:25:26,835 : INFO : collecting all words and their counts
# 2019-11-06 08:25:26,836 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-11-06 08:25:26,853 : INFO : collected 7165 word types from a corpus of 44635 raw words and 3083 sentences
# 2019-11-06 08:25:26,853 : INFO : Loading a fresh vocabulary
# 2019-11-06 08:25:26,864 : INFO : effective_min_count=10 retains 814 unique words (11% of original 7165, drops 6351)
# 2019-11-06 08:25:26,866 : INFO : effective_min_count=10 leaves 29755 word corpus (66% of original 44635, drops 14880)
# 2019-11-06 08:25:26,870 : INFO : deleting the raw counts dictionary of 7165 items
# 2019-11-06 08:25:26,871 : INFO : sample=0.001 downsamples 34 most-common words
# 2019-11-06 08:25:26,871 : INFO : downsampling leaves estimated 20601 word corpus (69.2% of prior 29755)
# 2019-11-06 08:25:26,875 : INFO : estimated required memory for 814 words and 300 dimensions: 2360600 bytes
# 2019-11-06 08:25:26,877 : INFO : resetting layer weights
# 2019-11-06 08:25:26,899 : INFO : training model with -1 workers on 814 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2019-11-06 08:25:26,908 : INFO : EPOCH - 1 : training on 0 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2019-11-06 08:25:26,910 : WARNING : EPOCH - 1 : supplied example count (0) did not equal expected count (3083)
# 2019-11-06 08:25:26,912 : WARNING : EPOCH - 1 : supplied raw word count (0) did not equal expected count (44635)
# 2019-11-06 08:25:26,919 : INFO : EPOCH - 2 : training on 0 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2019-11-06 08:25:26,921 : WARNING : EPOCH - 2 : supplied example count (0) did not equal expected count (3083)
# 2019-11-06 08:25:26,922 : WARNING : EPOCH - 2 : supplied raw word count (0) did not equal expected count (44635)
# 2019-11-06 08:25:26,928 : INFO : EPOCH - 3 : training on 0 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2019-11-06 08:25:26,930 : WARNING : EPOCH - 3 : supplied example count (0) did not equal expected count (3083)
# 2019-11-06 08:25:26,931 : WARNING : EPOCH - 3 : supplied raw word count (0) did not equal expected count (44635)
# 2019-11-06 08:25:26,939 : INFO : EPOCH - 4 : training on 0 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2019-11-06 08:25:26,940 : WARNING : EPOCH - 4 : supplied example count (0) did not equal expected count (3083)
# 2019-11-06 08:25:26,941 : WARNING : EPOCH - 4 : supplied raw word count (0) did not equal expected count (44635)
# 2019-11-06 08:25:26,949 : INFO : EPOCH - 5 : training on 0 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2019-11-06 08:25:26,952 : WARNING : EPOCH - 5 : supplied example count (0) did not equal expected count (3083)
# 2019-11-06 08:25:26,953 : WARNING : EPOCH - 5 : supplied raw word count (0) did not equal expected count (44635)
# 2019-11-06 08:25:26,955 : INFO : training on a 0 raw words (0 effective words) took 0.1s, 0 effective words/s
# Training model...

# %%
model.most_similar("frankenstein")
# Out:
# [('scenes', 0.16669809818267822),
#  ('allow', 0.16083307564258575),
#  ('affection', 0.15596412122249603),
#  ('former', 0.14493198692798615),
#  ('found', 0.1414320170879364),
#  ('m.', 0.138254776597023),
#  ('story', 0.13059641420841217),
#  ('letters', 0.12909497320652008),
#  ('beheld', 0.12585705518722534),
#  ('union', 0.1223391592502594)]

# %% [markdown]
# # TSNE Analysis

# %%
model
